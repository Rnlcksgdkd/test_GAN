# %% [markdown]
# <a href="https://colab.research.google.com/github/Rnlcksgdkd/test_GAN/blob/master/test_pkGAN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Rnlcksgdkd/test_GAN
# Out:
# Cloning into 'test_GAN'...
# remote: Enumerating objects: 117, done.
# remote: Counting objects: 100% (117/117), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 117 (delta 36), reused 106 (delta 25), pack-reused 0
# Receiving objects: 100% (117/117), 40.17 MiB | 10.14 MiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
# !pip install konlpy
# Out:
# Collecting konlpy
#   Downloading https://files.pythonhosted.org/packages/85/0e/f385566fec837c0b83f216b2da65db9997b35dd675e107752005b7d392b1/konlpy-0.5.2-py2.py3-none-any.whl (19.4MB)
#      |████████████████████████████████| 19.4MB 1.5MB/s
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (4.2.6)
# Collecting colorama
#   Downloading https://files.pythonhosted.org/packages/44/98/5b86278fbbf250d239ae0ecb724f8572af1c91f4a11edf4d36a206189440/colorama-0.4.4-py2.py3-none-any.whl
# Collecting JPype1>=0.7.0
#   Downloading https://files.pythonhosted.org/packages/cd/a5/9781e2ef4ca92d09912c4794642c1653aea7607f473e156cf4d423a881a1/JPype1-1.2.1-cp37-cp37m-manylinux2010_x86_64.whl (457kB)
#      |████████████████████████████████| 460kB 38.0MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from konlpy) (1.19.5)
# Collecting beautifulsoup4==4.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/d4/10f46e5cfac773e22707237bfcd51bbffeaf0a576b0a847ec7ab15bd7ace/beautifulsoup4-4.6.0-py3-none-any.whl (86kB)
#      |████████████████████████████████| 92kB 9.3MB/s
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.7/dist-packages (from konlpy) (3.10.0)
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->konlpy) (3.7.4.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests[socks]>=2.11.1 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tweepy>=3.7.0->konlpy) (1.15.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6; extra == "socks" in /usr/local/lib/python3.7/dist-packages (from requests[socks]>=2.11.1->tweepy>=3.7.0->konlpy) (1.7.1)
# Installing collected packages: colorama, JPype1, beautifulsoup4, konlpy
#   Found existing installation: beautifulsoup4 4.6.3
#     Uninstalling beautifulsoup4-4.6.3:
#       Successfully uninstalled beautifulsoup4-4.6.3
# Successfully installed JPype1-1.2.1 beautifulsoup4-4.6.0 colorama-0.4.4 konlpy-0.5.2

# %%
# %cd /content/test_GAN/pokemon_story_generator-master/pokemon_story_generator-master/2_seqgan
# Out:
# /content/test_GAN/pokemon_story_generator-master/pokemon_story_generator-master/2_seqgan

# %%
# !python load_embed.py
# Out:
# Loading ./embed/ko.tsv...
# Saved Complete ./embed/vec.txt !!

# %%
# !python preprocess_util.py

# %%
def _pkl_loading_test():
    # load sentences separated by pos (pkl)
    a = open('./data/pk_real_data.pkl', 'rb')
    sents = pickle.load(a)

    # load pos_list (pkl)
    a = open('./data/pk_pos_list.pkl', 'rb')
    pos_list = pickle.load(a)

    # load pos2idx (pkl)
    a = open('./data/pk_pos2idx.pkl', 'rb')
    pos2idx = pickle.load(a)

    # load idx2pos (pkl)
    a = open('./data/pk_idx2pos.pkl', 'rb')
    idx2pos = pickle.load(a)

    # load embedding_vec (pkl)
    a = open('./data/pretrain_embedding_vec.pkl', 'rb')
    embedding_vec = pickle.load(a)

    print(sents)
    print(len(pos_list))
    print(pos2idx)
    print(idx2pos)
    print(np.shape(embedding_vec))

_pkl_loading_test()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-2f05600b388d> in <module>()
#      26     print(np.shape(embedding_vec))
#      27
# ---> 28 _pkl_loading_test()
#
# <ipython-input-7-2f05600b388d> in _pkl_loading_test()
#       1 def _pkl_loading_test():
#       2     # load sentences separated by pos (pkl)
# ----> 3     a = open('./data/pk_real_data.pkl', 'rb')
#       4     sents = pickle.load(a)
#       5
#
# FileNotFoundError: [Errno 2] No such file or directory: './data/pk_real_data.pkl'

# %%
# !python preprocess_data.py
# Out:
# 1 세대
# 0      태어날 때부터 등에 식물의 씨앗이 있어 조금씩 크게 자란다.태어났을 때부터 등에 이...
# 1      꽃봉오리가 등에 붙어 있으며 양분을 흡수해가면 커다란 꽃이 핀다고 한다.등의 꽃봉오...
# 2      꽃에서 황홀한 향기가 퍼져나가 싸우는 자의 기분을 달래게 한다.태양 에너지를 영양으...
# 3      태어날 때부터 꼬리의 불꽃이 타오르고 있다. 불꽃이 꺼지면 그 생명이 다하고 만다....
# 4      꼬리를 휘둘러 상대를 쓰러트리고 날카로운 발톱으로 갈기갈기 찢어버린다.불타는 꼬리를...
#                              ...
# 146    새끼도 몸길이가 2미터 이상이다. 탈피를 거듭해서 몸집이 커진다.오랫동안 환상의 포...
# 147    바다나 호수 등에 산다고 한다. 날개가 없으나, 때때로 하늘을 나는 모습이 포착된다...
# 148    커다란 몸집으로 하늘을 난다. 지구를 약 16시간 만에 일주한다.모습을 본 사람은 ...
# 149    연구를 위해 이런저런 유전자를 이것저것 조합한 결과, 흉포한 포켓몬이 되어버렸다.한...
# 150    남아메리카에 서식하고 있는 절멸되었을 포켓몬. 지능이 높아 어떤 것이라도 습득한다....
# Name: desc, Length: 151, dtype: object
# 2 세대
# 0     머리의 잎사귀에서 살짝 달콤한 향기가 감돈다. 얌전하며 햇볕을 쬐는 것을 매우 좋아...
# 1     목 주변에서 나는 향긋한 향기를 맡으면 왠지 싸우고 싶어진다.목 주변에서 발산하는 ...
# 2     꽃잎에서 발산되는 향기에는 다투는 마음을 가라앉게 하는 성분이 담겨 있다.메가니움이...
# 3     겁이 많아서 늘 몸을 웅크리고 있다. 습격당하면 등의 불꽃을 타오르게 해서 몸을 보...
# 4     배틀 중에 등을 보이면 주의가 필요하다. 등의 불꽃으로 공격해올 것이라는 뜻이다.몸...
#                             ...
# 95    암반 같은 단단한 껍질로 둘러싸여 있지만 힘이 강해서 난동을 부리면 산도 무너져버린...
# 96    어떤 공격에도 꿈쩍도 하지 않는 몸을 가졌기 때문에 자꾸 승부를 걸어온다.주변 지형...
# 97    매우 강한 능력을 가졌기 때문에 깊은 바다 밑에서 조용히 시간을 보낸다고 전해진다....
# 98    무지개색의 훌륭한 날개로 세계의 하늘을 날고 있다는 신화로 전해지는 포켓몬이다.몸은...
# 99    시간을 넘어 여기저기를 방황한다.세레비가 모습을 나타낸 숲은 초목이 무성해진다고 한...
# Name: desc, Length: 100, dtype: object
# 3 세대
# 0      다리 뒤의 작은 가시를 박아 수직인 벽을 올라갈 수 있다. 굵은 꼬리로 힘껏 쳐서 ...
# 1      몸에서 난 잎사귀는 숲 속에서 적으로부터 몸을 숨길 때 편리하다. 밀림에 사는 나무...
# 2      몸에 난 잎사귀는 예리한 칼과 같다. 빠른 몸놀림으로 나뭇가지를 뛰어다니며 적의 머...
# 3      트레이너에게 바짝 붙어 아장아장 걷는다. 입에서 날리는 불꽃은 섭씨 1000도다. ...
# 4      산과 들을 뛰어다니며 하반신을 단련한다. 스피드와 파워를 겸비한 다리는 1초에 10...
#                              ...
# 130    하늘 전체를 덮는 비구름을 만들어 큰 비를 내리게 하는 힘을 가진 포켓몬. 가뭄으로...
# 131    대지를 쌓아올려 대륙을 넓힌 포켓몬이라고 신화로 전해진다. 가이오가와 사투 끝에 잠...
# 132    몇억년동안 오존층 속을 날아다니고 있으며 지상에는 절대로 내려오지 않는 포켓몬. 공...
# 133    깨어났을 때 머리에 있는 종이에 적힌 조원을 이루어준다는 전설을 가졌다. 위험을 느...
# 134    레이저를 쬔 우주 바이러스의 DNA가 돌연변이를 일으켜 태어난 포켓몬이다. 가슴의 ...
# Name: desc, Length: 135, dtype: object
# 4 세대
# 0      흙으로 만들어진 등껍질은 물을 먹으면 한층 단단해진다. 호수 근처에서 살고 있다.전...
# 1      숲 속의 물가에서 산다. 낮에는 숲 밖으로 나와서 등껍질의 나무에 빛을 쬔다.등껍질...
# 2      작은 포켓몬들이 모여 움직이지 않는 토대부기의 등에서 둥지를 만들려고 하는 경우가 ...
# 3      낭떠러지 절벽을 민첩하게 올라 바위산의 위에서 생활한다. 불꽃을 끄고 잠잔다.엉덩이...
# 4      꼬리의 불꽃을 길게 늘여 몸을 커 보이게 해서 습격해온 적에게 겁을 준다.천장이나 ...
#                              ...
# 102    따뜻한 바다에 사는 포켓몬이다. 머리의 부낭을 부풀려서 파도 사이를 떠돌며 먹이를 ...
# 103    차가운 바다 밑에서 태어났다. 자신이 태어난 바다의 밑바닥까지 긴 거리를 헤엄쳐서 ...
# 104    사람들을 깊은 잠으로 끌어들여 꿈을 보여주는 능력을 가지고 있다.그믐달이 뜨는 밤에...
# 105    꽃밭 속에서 살고 있지만 몸을 움크리면 꽃처럼 보이기 때문에 누구도 눈치채지 못한다...
# 106    1000개의 팔로 우주를 만든 포켓몬으로 신화에 묘사된다.우주가 아직 생기지 않았을...
# Name: desc, Length: 107, dtype: object
# 5 세대
# 0      승리를 이끄는 포켓몬이다.비크티니를 데리고 있는 트레이너는 그 어떠한 승부에서도 '...
# 1      지능이 높아 매우 냉정. 햇빛을 듬뿍 쬐면 움직임이 날카로워진다.꼬리로 태양의 빛을...
# 2      땅을 미끄러지듯 달린다. 빠른 움직임으로 상대를 혼란시키고 덩쿨채찍으로 꼼짝 못하게...
# 3      째려보는 것만으로 상대의 움직임을 멈춰버리게 한다. 태양 에너지를 몸 안에서 증폭시...
# 4      적의 공격을 가볍게 피해서 코에서 불의 구체를 쏘아낸다. 불꽃으로 나무열매를 구워서...
#                              ...
# 151    꼬리로부터 내리쬐는 에너지가 흙의 영양분을 증가시켜 작물이 크게 성장한다.랜드로스가...
# 152    강력한 냉기 에너지를 체내에서 만들어 내나 새어나온 그 냉기로 인하여 제 몸이 얼어...
# 153    발굽에서 물을 뿜어내는 것으로 수면을 미끄러 지듯이 이동. 특기인 다리기술로 싸운다...
# 154    특수한 발성법으로 노래하는 멜로디는 들은 자의 감정을 자유자재로 조종한다.메로엣타가...
# 155    3억년 전에 최강의 헌터로서 두려움의 대상이었다. 플라스마단에게 개조 당했다.플라스...
# Name: desc, Length: 156, dtype: object
# 6 세대
# 0     머리의 가시는 평소에는 부드럽지만 힘을 주면 뾰족하고 날카로워지며 바위를 뚫어 버릴...
# 1     몸을 둘러싼 단단한 껍질이 적의 공격을 튕겨내고 날카로운 가시로 반격한다.동료끼리 ...
# 2     몸통박치기로 50톤 전차를 뒤집는 파워를 지녔다. 자신이 방패가 되어 동료를 지킨다...
# 3     잔가지를 먹으면 힘이 나서 섭씨 200도가 넘는 열기를 커다란 귀에서 내뿜는다.작은...
# 4     나뭇가지를 꼬리에 꽂고 있다. 꼬리털의 마찰열로 가지에 불을 붙여 싸운다.나뭇가지를...
#                             ...
# 67    날개와 꼬리를 펼치고 빨갛게 빛날 때 살아 있는 생명을 빨아들이는 전설의 포켓몬.수...
# 68    날카로운 이빨로 상대를 처리한다. 계속 이 몸을 유지할 수 없어서 일정 시간이 지나...
# 69    멜리시의 돌연변이다. 분홍빛으로 빛나는 몸은 세계에서 가장 아름답다고 일컬어진다.양...
# 70    공간을 뒤트는 링으로 모든 것을 멀리 떨어진 곳으로 날려버리고 마는 트러블메이커다....
# 71    수증기를 뿜어내어 자신의 모습을 짙은 안개 속에 숨긴다. 사람이 오지 않는 산에 산...
# Name: desc, Length: 72, dtype: object
# 7 세대
# 0     경계심이 강하다. 낮에는 광합성으로 힘을 비축하고 밤이 되면 활동을 개시한다.전혀 ...
# 1     젠체하고 틈만 나면 날개의 손질을 한다. 깃털의 얼룩이 신경 쓰여 싸우지 못할 때도...
# 2     날개에 숨겨진 살깃을 시위에 메겨서 날린다. 100m 앞의 작은 돌도 관통하는 정밀...
# 3     혀로 털을 정리하면서 배에 쌓인 빠진 털을 태워서 불을 뿜는다. 털을 뱉어내는 방법...
# 4     목 주변에 불꽃의 방울이 있다. 불꽃을 뿜어낼 때 딸랑딸랑 높은 소리가 난다.앞발의...
#                             ...
# 83    등장하지 않음울트라홀에서 출현했다. 여러 개의 생명이 쌓여 1마리를 형성하고 있는 ...
# 84    등장하지 않음꿈틀거리며 사람에게 다가오다 느닷없이 머리를 폭발시킨다. 울트라비스트의...
# 85    등장하지 않음양 손발톱에 전기를 머금어 상대를 갈가리 찢는다. 피하더라도 흩날리는 ...
# 86    등장하지 않음걸쭉하게 녹은 강철의 몸을 가졌다. 땅속의 철분이나 금속을 녹여서 흡수...
# 87    등장하지 않음철을 만들어내는 힘을 가졌다고 추앙받았었다. 모종의 이유로 3000년의...
# Name: desc, Length: 88, dtype: object
# Create Sequence in a length of seq_length...
# Complete Creating sequence !!
# Replace Sequence to Index...
# Complete Creating sequence to index !!

# %%
# !python sequence_gan.py
# Out:
# 2021-04-13 07:18:59.827345: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# {0: '<start>', 1: '하', 2: '이', 3: 'ㄴ', 4: '의', 5: '는', 6: '다', 7: '에', 8: '을', 9: '었', 10: '은', 11: '되', 12: '를', 13: '어', 14: '고', 15: '있', 16: '가', 17: '아', 18: '으로', 19: '로', 20: '에서', 21: '년', 22: 'ㄹ', 23: 'ㄴ다', 24: '과', 25: '들', 26: '도', 27: '지', 28: '일', 29: '것', 30: '그', 31: '게', 32: '와', 33: '오', 34: '기', 35: '였', 36: '늘', 37: '여', 38: '수', 39: '등', 40: '며', 41: '더', 42: '나', 43: '시', 44: '으며', 45: '라', 46: '주', 47: '않', 48: '았', 49: '리', 50: '대하', 51: '카', 52: '부터', 53: '에게', 54: '때', 55: '어서', 56: '만', 57: '위하', 58: '면', 59: '저', 60: '보', 61: '세', 62: '없', 63: '후', 64: '르', 65: '키', 66: '지만', 67: '자', 68: '중', 69: '받', 70: '까지', 71: '같', 72: '는데', 73: '따르', 74: '사용', 75: '라는', 76: '라고', 77: '두', 78: '위', 79: '니', 80: '대', 81: '타', 82: '크', 83: '전', 84: '경우', 85: '가지', 86: '적', 87: '으나', 88: '알', 89: '한', 90: 'ㅁ', 91: '의하', 92: '지역', 93: '마', 94: '사람', 95: '때문', 96: '면서', 97: '사', 98: '서', 99: '미', 100: '시키', 101: '많', 102: '성', 103: '군', 104: '만들', 105: '명', 106: '개', 107: '바', 108: '아니', 109: '다고', 110: '제', 111: '또는', 112: '이름', 113: '레', 114: '코', 115: '부', 116: '이나', 117: '말', 118: '다른', 119: '우', 120: '위치', 121: '티', 122: '노', 123: '현재', 124: '안', 125: '내', 126: '정', 127: '또한', 128: '호', 129: '히', 130: '차', 131: '데', 132: '함께', 133: '세계', 134: '자신', 135: '조', 136: '다음', 137: '가장', 138: '비', 139: '그러나', 140: '왕', 141: '다는', 142: '당시', 143: '쿠', 144: '토', 145: '시대', 146: '네', 147: '구', 148: '사이', 149: '강', 150: '남', 151: '보다', 152: '말하', 153: '어야', 154: '상', 155: '쓰', 156: '씨', 157: '통하', 158: '뒤', 159: '하나', 160: '인', 161: '디', 162: '도시', 163: '역', 164: '베', 165: '활동', 166: '산', 167: '이르', 168: '시작', 169: '여러', 170: '못하', 171: '아서', 172: '지방', 173: '포함', 174: '문제', 175: '거나', 176: '신', 177: '중국', 178: '주의', 179: '다시', 180: '속', 181: '동', 182: '장', 183: '로서', 184: '번째', 185: '전쟁', 186: '선', 187: '모든', 188: '슬', 189: '스', 190: '그리', 191: '파', 192: '소', 193: '존재', 194: '다가', 195: '요', 196: '보이', 197: '일부', 198: '이용', 199: '모두', 200: '글', 201: '세기', 202: '이상', 203: '살', 204: '란', 205: '메', 206: '듣', 207: '사건', 208: '내용', 209: '연구', 210: '점', 211: '아들', 212: '생각', 213: '야', 214: '종', 215: '원', 216: '치', 217: '회', 218: '간', 219: '곳', 220: '새', 221: '주장', 222: '기록', 223: '길', 224: '테', 225: '나오', 226: '잇', 227: '유', 228: '또', 229: '의미', 230: '벌', 231: '문화', 232: '도록', 233: '부분', 234: '관련', 235: '섬', 236: '관계', 237: '피', 238: '당', 239: '처음', 240: '개발', 241: '터', 242: '인하', 243: '정도', 244: '약', 245: '구성', 246: '필요', 247: '대부분', 248: '기술', 249: '발생', 250: '불리', 251: '프', 252: '이에', 253: '시간', 254: '다르', 255: '당하', 256: '하여', 257: '알리', 258: '운동', 259: '동안', 260: '팀', 261: '정보', 262: '여기', 263: '작', 264: '각', 265: '작품', 266: 'ㄴ다는', 267: '으로서', 268: '높', 269: '죽', 270: '영화', 271: '무', 272: '중심', 273: '선수', 274: '상태', 275: '문', 276: '가능', 277: '화', 278: '이자', 279: '드', 280: '하다', 281: '초', 282: '같이', 283: '포', 284: '설치', 285: '아이', 286: '뜻', 287: '부르', 288: '발견', 289: '과정', 290: '형태', 291: '러', 292: '공격', 293: '특히', 294: '첫', 295: '기관', 296: '나라', 297: '루', 298: '겠', 299: '관리', 300: '프로', 301: '이루어지', 302: '모', 303: '쓰이', 304: '랜드', 305: '해', 306: '전투', 307: '헤', 308: '분', 309: '방법', 310: '얻', 311: '양', 312: '박', 313: '최초', 314: '일어나', 315: '곡', 316: '법', 317: '경', 318: 'ㄴ다고', 319: '등장', 320: '좋', 321: '공', 322: '닿', 323: '발전', 324: '용', 325: '영향', 326: '하지만', 327: '발표', 328: '뿐', 329: '개의', 330: '음', 331: '결과', 332: '이것', 333: '세우', 334: '이유', 335: '계속', 336: '지내', 337: '낳', 338: '번', 339: '계', 340: '외', 341: '매우', 342: '음악', 343: '반', 344: '잘', 345: '많이', 346: '려', 347: '사실', 348: '회사', 349: '중앙', 350: '판', 351: '집', 352: '진', 353: '목적', 354: '사망', 355: '손', 356: '총', 357: '배', 358: '주로', 359: '천', 360: '중요', 361: '독립', 362: '분류', 363: 'ㄹ라', 364: '결정', 365: '조직', 366: '롭', 367: '이루', 368: '식', 369: '갈', 370: '으로써', 371: '자유', 372: '처럼', 373: '방식', 374: '북', 375: '단체', 376: '자리', 377: '참여', 378: '재', 379: '인간', 380: '츠', 381: '거치', 382: '주요', 383: '다양', 384: '계획', 385: '대신', 386: '빌', 387: '프로그램', 388: '여성', 389: '윤', 390: ' ...
# 17092
# Traceback (most recent call last):
#   File "sequence_gan.py", line 121, in <module>
#     tf.reset_default_graph()
# AttributeError: module 'tensorflow' has no attribute 'reset_default_graph'

# %%
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@6e9bcdd1347e.(none)')
# fatal: unable to access 'https://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@f@github.com/Rnlcksgdkd/test_GAN/': Could not resolve host: f@github.com
